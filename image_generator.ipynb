# %%
import torch
from diffusers import StableDiffusionPipeline
from PIL import Image
from IPython.display import display

# !pip install -q diffusers accelerate

# %%
if torch.cuda.is_available():
    device = "cuda"
    dtype = torch.float16
    print("GPU detected! Running on CUDA...")
else:
    device = "cpu"
    dtype = torch.float32
    print("GPU not available.")
# Out:
# GPU detected! Running on CUDA...

# %%
pipe = StableDiffusionPipeline.from_pretrained(
    "runwayml/stable-diffusion-v1-5",
    torch_dtype=dtype
)
pipe = pipe.to(device)
# Out:
# Loading pipeline components...:   0%|          | 0/7 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/396 [00:00<?, ?it/s]
# Loading weights:   0%|          | 0/196 [00:00<?, ?it/s]

# %%
user_prompt = input("\nEnter Image Prompt: ")

# 3. Generate & Display Image
print("\nGenerating Image")
image = pipe(user_prompt).images[0]

display(image)
image.save("generated_image.png")
print("\nImage Generated Successfully and saved as generated_image.png!")
# Out:
# Enter Image Prompt: Breathtaking mountain landscape at sunrise, golden light hitting snow-capped peaks, mirror-like alpine lake reflection, wildflowers in foreground, atmospheric fog in valley, National Geographic quality
#
# Generating Image
#   0%|          | 0/50 [00:00<?, ?it/s]
# <PIL.Image.Image image mode=RGB size=512x512>
# Image Generated Successfully and saved as generated_image.png!
